# %%
# parameters
input_size = 200

# %%
print('witam')
# Out:
# witam

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0, input_size, 1)
y = np.random.gamma(2., 2., input_size)
plt.figure(figsize=(18,10))
plt.scatter(x, y, c='r')
plt.savefig("test.png")
plt.show()

# %%
from result_saver import ResultSaver

def half_of_input(input_size):
    return input_size/2

result = {
    "task1": half_of_input(input_size)
}

ResultSaver().save_result(result)
# Out:
# 100.0
